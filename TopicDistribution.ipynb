# %%
import pandas as pd

# %%
BASE = 'C:\\Users\\basharm\\PythonJupyter\\CoVID19CodeGit\\data\\initial_data\\'

# %%
#df = pd.read_csv(BASE+'tweet_out.txt', sep = '\t', encoding = 'utf8')

# %%
df = pd.DataFrame(columns = ['Tweet', 'created_at', 'location', 'verified', 'name', 'followers_count', 'friends_cout'])
df
# Out:
# Empty DataFrame
# Columns: [Tweet, created_at, location, verified, name, followers_count, friends_cout]
# Index: []

# %%
df = pd.DataFrame([['south first patient home via', 'Mon Mar 09 05:54:02 +0000 2020', 'Global', 'True', 'ZimEye', '91046', '11777']])

# %%
df
# Out:
#                               0                               1       2     3  \
# 0  south first patient home via  Mon Mar 09 05:54:02 +0000 2020  Global  True
#
#         4      5      6
# 0  ZimEye  91046  11777

# %%
df = None
with open(BASE+'tweet_out.txt', encoding='utf') as FI:
    lines = []
    for line in FI:
        line = line.strip().split('\t')
        lines.append(line)
    df = pd.DataFrame(lines)
df.columns = list(df.iloc[0])
df
# Out:
#                                            Tweet  \
# 0                                          Tweet
# 1                   south first patient home via
# 2                                          japan
# 3                 Mon Mar 09 05:54:01 +0000 2020
# 4                 Mon Mar 09 05:54:01 +0000 2020
# ...                                          ...
# 859299  half A million death leak paper show via
# 859300                      prevent import novel
# 859301            Sat Mar 07 11:48:47 +0000 2020
# 859302                      might think good via
# 859303            Sat Mar 07 11:48:47 +0000 2020
#
#                             created_at          location          verified  \
# 0                           created_at          location          verified
# 1       Mon Mar 09 05:54:02 +0000 2020            Global              True
# 2       Mon Mar 09 05:54:02 +0000 2020                               False
# ...
